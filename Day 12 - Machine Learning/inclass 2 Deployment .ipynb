# %% [markdown]
# ### $$Deployment$$

# %% [markdown]
# - is all about MLOps
# - if you have a model, where are you keeping it?
#     - own system or PC | remote server | github
#     - how are you accessing the model: using a web app | mobile app | PC software
#     - usage, how many users are using it/ will use it
#         - you will allocate resources to the app
#         - remote server on AWS, Azure, GCP - need to buy - more RAM - more Uptime
#     - remote server: remote ALWAYS ON, computer system
# -
# - Not MLOps engineers yet
# -
# - if we have a model, there should be a way to share it with others, or let others use it
# - ways we do it are the following:
#     1. Streamlit
#     2. Flask
#     3. common now: because of AI tools: WEB APPS + backend
#     4. we will use an inpython tool called Gradio to do it - UI for our model in notebook as well

# %%
# pip install gradio

# %%
import gradio as gr

# %%
# build an interface with gradio
demo = gr.Interface(
    fn = lambda x : x ,
    inputs = 'text',
    outputs= 'text',
    title= "our FIRST app!"
)

# demo.launch()

# use the .launch() to see the app

# %%
# Define the function to execute

def greet(name):
    return f"Welcome to the APP,  traveller {name}!"

app = gr.Interface(
    fn = greet,
    inputs= 'text',
    outputs= 'text'
)

# app.launch()

# %% [markdown]
# ## Deploy a model
# - we must create or train a model first
# -

# %%
# Loading a Pretrained Model

# let's use the model pickle file
# rb - read binary mode
import pickle

with open("DT_iris_Classifier.pkl", "rb") as file:
    model = pickle.load(file)

# %%
type(model)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
# test that model
model.predict([[2,3,4,5]])[0]
# Out:
# c:\Users\devid\Desktop\Nexperts Academy\AIML-nexperts4\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'virginica'

# %%
# to build a UI for the model

def predict_species(sl,sw,pl,pw):

    input_data = [[sl, sw, pl, pw]]

    predictions = model.predict(input_data)

    return predictions[0]

# %%
predict_species(2,3,4,5)
# Out:
# c:\Users\devid\Desktop\Nexperts Academy\AIML-nexperts4\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'virginica'

# %%
# UI

app = gr.Interface(
    fn = predict_species,
    inputs = [
        gr.Number(label= "Sepal Length", value= 3),

        gr.Dropdown(choices=[2,3,4,4.5], label = "Sepal Width", value= 3),

        gr.Radio(choices=[2,3,4,4.5], label = "Petal Length",value= 3),

        gr.Slider(0, 3, label = "Petal Width",value= 3)
    ],
    outputs= 'text',
    title= "The IRIS species identifier",
    description= "describe everything here about the app",
    article= "*Our website [here](https://gradio.live/)*",
    
    flagging_mode= 'never'

)

app.launch(share= True)
# Out:
# * Running on local URL:  http://127.0.0.1:7867
# * Running on public URL: https://f2f61ebe88b38956c6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f2f61ebe88b38956c6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Please deploy your model over the hugging face spaces
