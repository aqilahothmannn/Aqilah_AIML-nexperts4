# %% [markdown]
# ### Supervised Learning algo
# - there needs to be labeled data
# -

# %% [markdown]
# - **Classification**:
#     - Logistic Regression - best to separate two classes - e.g. Spam,  Not Spam
#     - Decision Trees -
#     - K nearest neighbours - primarily
#     - SVM - data is layed out, and a decision boundary line is built
#
# - **Regression**:
#     - Linear Regression: for numbers as values
#     - Decision Trees -
#     - not generally used/preffered ----
#     - K nearest neighbour -
#     - SVM
#     -

# %% [markdown]
# All of the models have their own way of working
# - own maths behind
# - and logic
#
#
# How these models make decisions
# - most will have an Error Function - to calculate the error in the predictions
# -
